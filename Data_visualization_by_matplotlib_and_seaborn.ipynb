# %% [markdown]
# <a href="https://colab.research.google.com/github/yashwardha-n/first_sem_project/blob/main/Data_visualization_by_matplotlib_and_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###What is data visualization
# Data visualization refers to the graphical representation of data to communicate information clearly and efficiently. It involves using visual elements like charts, graphs, and maps to present complex datasets in a more understandable and insightful manner.

# %% [markdown]
# ###What is Matplotlib?
#
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# Matplotlib was created by John D. Hunter.
#
# Matplotlib is open source and we can use it freely.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ###line plot
# Line plots in Matplotlib are widely used for visualizing data where one variable changes over another.

# %%
#title, label, xlabel, ylabel

# %% [markdown]
# ###Set Font Properties for Title and Labels
#
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
cgpa = np.array([6, 6.8, 7, 7.5, 8, 8.5, 10])
pacakge = np.array([5, 6, 7, 7.5, 8, 10, 30])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Shoolini university students of BTECH", fontdict = font1)
plt.xlabel("CGPA of students", fontdict = font2)
plt.ylabel("Package of students", fontdict = font2)

plt.plot(cgpa, pacakge,"o--r",  ms = 20, mec = "r", mfc = "g") # ms is marker size, mec marker edge color
plt.grid(axis = "y",color = "g", linestyle = ":")
plt.show()

# %% [markdown]
# ###Creating Bars
#
# With Pyplot, you can use the bar() function to draw bar graphs:

# %% [markdown]
# Bar plots in Matplotlib are used to represent categorical data with rectangular bars.

# %%
fruit = np.array(["Apple", "Banana", "Orange", "watermelon"])
fruit_number = np.array([100, 80, 120, 50])
color = ["red", "green", "yellow", "hotpink"]
plt.bar(fruit, fruit_number, color = color)
plt.show()

# %%
fruit = np.array(["Apple", "Banana", "Orange", "watermelon"])
fruit_number = np.array([100, 80, 120, 50])
color = ["red", "green", "yellow", "hotpink"]
plt.barh(fruit, fruit_number, color = color)
plt.show()

# %% [markdown]
# ###pie plot
# Pie plots in Matplotlib are useful for representing data as a circular statistical graphic. Each wedge of the pie represents a proportion of the whole.

# %%
x = np.array([25, 35, 20, 20])
my_labels = ["Apple", "Banana", "Orange", "watermelon"]
my_explode = [0, 0.2, 0, 0]
plt.pie(x, labels = my_labels, explode = my_explode)
plt.legend(title = "Myfruit")
plt.show()

# %% [markdown]
# ###scatter plot
# Scatter plots in Matplotlib are used to visualize the relationship between two variables by displaying data points as individual markers.

# %%
age_cars = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
speed_cars = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(age_cars, speed_cars)
plt.title("Cars data")
plt.xlabel("age of cars")
plt.ylabel("Speed of cars")
plt.show()

# %% [markdown]
# ###Histogram
# Histogram plots in Matplotlib are used to visualize the distribution of a single continuous variable by dividing the data into bins and displaying the frequency or count of observations in each bin.

# %%
# Sample data
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5, 5, 6, 6, 6, 6, 6, 7, 7, 8]

# Create a histogram plot
plt.hist(data, bins=8, color='skyblue', edgecolor='black')

# Add title and labels
plt.title('Histogram Plot Example')
plt.xlabel('Values')
plt.ylabel('Frequency')

# Display the plot
plt.show()
